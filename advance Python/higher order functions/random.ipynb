# %%
# there are 3 higher oredr functions 1. filter function, 2.




l=[1,2,3,4,5,6]
# ans=[]
# ans1=[]
# ans2=0
# for i in range(0,len(l)):
#     if i % 2 == 0:
#         ans.append(l[i])
#     ans1.append(l[i]*2)
#     ans2+=l[i]
# print(ans)
# print(ans1)
# print(ans2)
# ------------------------------------------
# l=[1,2,3,4,5,6]
# ans=[]
# ans1=[]
# ans2=0
# for i in l:
#     if i % 2 == 0:
#         ans.append(i)
#     ans1.append(i*2)
#     ans2+=i
# print(ans)
# print(ans1)
# print(ans2)

#-------------------------------------------

# def odd_filter(n):
#     if n%2==1:
#         return True
# print(list(filter(odd_filter,l)))

#-------------------------------------------

print(list(filter(lambda n:n%2==1,l)))

print(list(map(lambda n:n*2,l)))
# Out:
# [1, 3, 5]
# [2, 4, 6, 8, 10, 12]
