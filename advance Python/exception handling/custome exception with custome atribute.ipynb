# %%
class weekpassworderror(Exception):
    def __init__(self, password, msg):
        self.password = password
        self.msg = msg
try:
    user_password = input('enter a password: ')
    if len(user_password) < 8:
        raise weekpassworderror(user_password, 'password doesnot have 8 char')
except weekpassworderror as E:
    print(f"inalid password - {E.password}  {E.msg}")
else:
    print(f'strong password -{user_password}')
# Out:
# inalid password - 12345  password doesnot have 8 char

# %%
# using --str-- to call a msg  

class weekpassworderror(Exception):
    def __init__(self, password):
        self.password = password
    def __str__(self):
        return f"invalid password doesnot have 8 char {self.password}"
    # or we can print the password here only using self.variable
       
user_password = input('enter a password: ')   

try:
    
    if len(user_password) < 8:
        raise weekpassworderror(user_password)
except weekpassworderror as E:
    print(user_password, E)
    # or we can use
    print(E.password, E)


else:
    print(f'strong password -{user_password}')
# Out:
# 1233 invalid password doesnot have 8 char 1233
# 1233 invalid password doesnot have 8 char 1233
