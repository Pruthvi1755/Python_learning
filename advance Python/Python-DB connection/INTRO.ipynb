# %% [markdown]
# <!-- **Python DataBase Connection** -->
# -it helps us to save data which is present in python file to the external database
# -this process helps us to convert data as a permenent data
# -first install external module which helps us to connect python and mysql
#   "pip install pymysql"
#
#               Python ----->pymysql<------- MySQL
#
# <!-- *steps to connect python and Mysql* -->
#
# 1. need to import the module (import pymysql)
#
# 2. use connect method to connect python file &  mysql by passing credentia
#    <!-- *"variable1 = pymysql.connect(para1,para2,para3)" -->
#                                 |     |     |
#                                 V     V     V
#                           username password host
#
# 3. create a cursor object with the help of connection object and cursor method.
#    <!-- *"variable2 = variable1.cursor()" -->
#    <!-- *"cur_obj = con_obj.cursor" -->
#
# 4. use execute method to run the sql queries.
#    <!-- *"cur_obj.execuyr("----sql queries----")" -->
#
# 5. use exucute many method when we need to deal with multiple data
#    <!-- *"executemany(para1,para2)" -->
#
# 6. use looping statements to display the data
#
# 7. use commit method when we are performing add, update & delete functionality
#
# 8. use rollback method when handling the exception.
#
# 9. close the connection

# %%
# example 1

import pymysql

con_obj = pymysql.Connect(
    user='root',
    password='root'
    host='localhost'
)
print(con_obj)
# Out:
#   Cell In[1], line 7
#     password='root'
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
