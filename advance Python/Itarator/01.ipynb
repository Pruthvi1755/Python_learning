# %% [markdown]
# <!-- **Itarators** -->
#
# 1. Iterators is an obj which helps us to iterate over the itrerable type valuses and fetch one vale at a time when it is requried

# %%
l1 = [1,2,3,4,5]
list_iter = l1.__iter__()
# list_iter.__next__() # *first element
# list_iter.__next__() # *second element
# list_iter.__next__() # *third element
# list_iter.__next__() # *forth element
# list_iter.__next__() # *fifth element
# list_iter.__next__() # *error

# %%
# *wap to display the list element by manually handling the stop itreration execution

l1 = [1,2,3,4,5]
list_it = l1.__iter__()

while True:
    try:
        print(next(list_it))
    except :
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# *wap to display first 10 natural numbers using custom itreator

class Numbers:
    def __init__(self):
        return self
    
    def __next__(self):
        if self.num <=10:
            res = self.num
            self

# %% [markdown]
# <!-- * difference btw iterators and looping -->
# iterators-
# 1. it provides explicets control over the iteration proces.
# 2. it requeries more code and need to handle stop iteration exception excepcitly.
# 3. it allows the user to write custom iterator logic over the iteration process.
# 4. it maintains its own states and logic over the itreration and stops when it is requried
#
# looping--
# 1.it provides impecit control over the iteration process and handles the loop and fetch all the values and handles stop itreation exception.
# 2. no need to have more code, it is easy to write, easy to read and easy to maintain.
# 3. it is fixed over the default itreation logic provided by the __iter__ ().
# 4. it doesnt allows user to provide itreation logic

# %%
# * using custom itreator logic display all the even numbers present in a list one after the another
