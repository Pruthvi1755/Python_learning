# %%
# function returning a function 
def outer_fun(num):
    def inner_fun1():
        print("i am Ragnar LOthbrok")
    def inner_fun2():
        print("i am bjron ironside")
    if num % 2 == 0:
        return inner_fun1
    else:
        return inner_fun2
val=outer_fun(3)
val()
# Out:
# i am bjron ironside
