# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('score_updated.csv', encoding = 'latin-1')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
x = df.drop('Scores', axis=1)
y=df['Scores']
x.head()
# Out:
#    Hours
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5

# %%
x.shape
# Out:
# (96, 1)

# %%
y.shape
# Out:
# (96,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=5, test_size=0.2)

# %%
x_train.shape
# Out:
# (76, 1)

# %%
y_train.shape
# Out:
# (76,)

# %%
x_test.shape
# Out:
# (20, 1)

# %%
y_test.shape
# Out:
# (20,)
