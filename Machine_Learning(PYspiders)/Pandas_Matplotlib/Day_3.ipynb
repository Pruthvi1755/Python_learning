# %%
import pandas as pd
df = pd.read_csv("NarutoData.csv")

# ninja=df[df["Intelligence"]>=9] 
# print(ninja)




# unique() numunique() value_counts() 
# print(df.mean(numeric_only=True))
# print(df.sum(numeric_only=True))
# print(df["Power"].sum())
# print(df["Power"].min())
# print(df["Power"].max())
# print(df.count())

# group by function

# clan = df.groupby("Clan")
# print(clan["Power"].mean())


# print(df.head(10).to_string())
df[df['Power'] > 9]
# Out:
#     No              Name Village      Clan              Power1  \
# 0    1    Naruto Uzumaki    Leaf   Uzumaki  Shadow Clone Jutsu
# 1    2     Sasuke Uchiha    Leaf    Uchiha             Chidori
# 4    5     Itachi Uchiha    Leaf    Uchiha            Genjutsu
# 15  16   Minato Namikaze    Leaf  Namikaze  Flying Thunder God
# 16  17   Kushina Uzumaki    Leaf   Uzumaki       Chakra Chains
# 17  18           Tsunade    Leaf     Senju    Medical Ninjutsu
# 18  19           Jiraiya    Leaf       NaN     Summoning Jutsu
# 19  20        Orochimaru   Sound       NaN    Snake Techniques
# 21  22     Madara Uchiha    Leaf    Uchiha           Sharingan
# 22  23      Obito Uchiha    Leaf    Uchiha               Kamui
# 23  24    Nagato Uzumaki    Rain   Uzumaki            Rinnegan
# 34  35        Killer Bee   Cloud       NaN     Lightning Style
# 35  36    Fourth Raikage   Cloud       NaN     Lightning Armor
# 37  38             Onoki   Stone       NaN        Dust Release
# ...
