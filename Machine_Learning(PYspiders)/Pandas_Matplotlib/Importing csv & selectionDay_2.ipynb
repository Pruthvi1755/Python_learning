# %%
import pandas as pd

df = pd.read_csv("NarutoData.csv", index_col="Village")

# selection by column

# print(df["Name"].to_string())
# print(df[["Name", "Power","SpecialPower"]].to_string())

# selection by Row/s

# print(df.loc["Minato Namikaze"])
# print(df.loc["Itachi Uchiha",["Power1", "Power2"]])
# print(df.loc["Tsunade":"Hashirama Senju",["Power1", "Power2","SpecialPower"]])

# print(df.iloc[0:20:2, 3:6].to_string())

# village = input("Enter a village name: ")

# try:
#   print(df.loc[village].to_string())

# except KeyError:
#   print(f"{village} not found.")

# legendary_Ninjas = df[df["Legendary"]== True]
# powerfull_Ninjas = df[df["Power"]>+9]
# intelligent_Ninjas = df[df["Intelligence"]==5]
df.dropna()
df.tail()
# Out:
#           No              Name      Clan             Power1            Power2  \
# Village
# Leaf      96   Inojin Yamanaka  Yamanaka      Ink Creatures     Mind Transfer
# Sand      97              Yodo       NaN    Sound Detection      Kunai Combat
# Sand      98             Araya       NaN      Puppet Combat  Iron Sand Shield
# Mist      99  Kagura Karatachi       NaN       Sword Combat       Water Style
# Mist     100           Chojuro       NaN  Sword Hiramekarei       Water Style
#
#             SpecialPower TailedBeast  Power  Intelligence  Legendary
# Village
# Leaf     Art Style Jutsu         NaN    7.7             4          0
# Sand          Wind Sense         NaN    7.3             4          0
# Sand        Hidden Blade         NaN    7.5             3          0
# Mist       New Swordsman         NaN    7.9             4          0
# Mist      Mizukage Power         NaN    9.0             4          1
