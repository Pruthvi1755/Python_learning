# %%
import numpy as np
arr = np.array(([1,11,44],[2,22,55],[3,33,66],[4,44,77],[5,55,88]))

# %%
# user = input('enter your choice: ')
# l = ['rock', 'paper', 'cut']
# computer = np.random.choice(l)
# if user == "rock" and computer == 'rock':
#   print(f"draw , {computer} and {user}" )
# elif user == "rock" and computer == 'paper':
#   print(f"lose, {computer} and {user}")
# elif user == "rock" and computer == 'cut':
#   print(f"win, {computer} and {user}")
# elif user == "paper" and computer == 'paper':
#   print(f"draw, {computer} and {user}")
# elif user == "paper" and computer == 'rock':
#   print(f"win, {computer} and {user}")
# elif user == "paper" and computer == 'cut':
#   print(f"lose, {computer} and {user}")
# elif user == "cut" and computer == 'rock':
#   print(f"lose, {computer} and {user}")
# elif user == "cut" and computer == 'paper':
#   print(f"win, {computer} and {user}")
# elif user == "cut" and computer == 'cut':
#   print(f"draw, {computer} and {user}")
# # else:
#   print('incorrect')
