# %%
**Encodings**
it is a ML preprocessing technique which converts categorical values (strings) into numerical

techinques:
    1.lable encoda
    2.one hot encoder
    3.ordinal encoder
    4.target encoder

1.lable Encoder -
     it is a encoding preprcessing technique which accepts only one columns and encodes the values from 0

# %%
# Lable Encoder
from sklearn.preprocessing import LabelEncoder
encodes = LabelEncoder()
# 1.
encodes.fit_transform(x_train[column_name])
# 2.
encodes.fit_transform(x_train[column_name])
encodes.transform(x_test[column])
encodes.transform(x_test[column])

# %%
How it works?

col1     selets unique valuse      assigns the value from zero
_____           _____                         a11->0  
|a11|           |a11|                         a12->1
|a12|           |a12|                         a13->2    
|b1 |           |a13|                         b1 ->3
|a13|           |b1 |  
|___|           |___|  

**when to use lable Encoder**
-when we have only catagorical column
-for less unique values
-mostly we use this for target column

**when not to use lable Encoder**
-more than one catagorical column

for transformes model had already learnt the pattern for training data 
so no need to use again fit_transform() directly we can go with transform()

# %%
2.One Hot Encoders
it accepts 2d and encodes binary values 

**when to use it**
-when featuers columns are having two or more columns then we use One Hot Encoders
-used when less unique values

**when not to use lable Encoder**

# %%
3.Ordinal Encoders
-it encodes the value based on order
-it accepts only 2d
-if we assign the values it assigns directly

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
encoder = OneHotEncoder(handle_unknown="ignore"|"error"(default), sparse_output=True/False default)
encoder = OrdinalEncoder(catagories = [col_1 order], [col_2 ,order])

encoder.fit_transform(x_train)4
encoder.fit_transform(x_train[['col_s']])
