# %% [markdown]
# MAE = z|yi - y^|/n
# RMSE = sqt(yi^2)/n

# %%
# # from sk learn metrics import mean_squared_error , mean_absoluts_error, root_mean_squared_error, r2_score
# #  syntax for metrics
# metrics name(ytrain, y pred)
#            actual output, preditded op


#1. model = linear regression()
#2. model fit(xtrain, ytrain)
#          fit>finds mx+c m,c
#3. model.predict(x)


# example: actual output => ytrain, ytest
# train data :
# actual output => ytrain
# predicted output => modle.predict
