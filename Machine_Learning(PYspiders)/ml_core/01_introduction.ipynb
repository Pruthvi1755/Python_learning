# %%
# Machine learning : it is a subset of ai and it trains the model which understand the patterns by default and predicts the outcome

# why ml?
# 1 by defaulty understand the patterns
# 2 maintain huge amount of data
# 3 make better predictions
# 4 increase accuracy overtime

# types of Machine learning
# 1 Supervised learning
#      * Regression
#      * Classification
# 2 Unsupervised learning
#      * Clustering
#      * pca

# %%
# regression : it is ml or statical learning it predict the continue value by understanding the relation between independent and dependent columns
# types of regression
# 1 Linear regression
# 2 Polynomial regression
# 3 Logistic regression
# how to find the relation between columns
# 1 corr()
# 2 scatter plot()

# %% [markdown]
# what is regression?
# when to use regression--if output column has having contionus column then we use it
# regression will produce continous values
#
# independet column - input
# dependent column output
#
#
# co variance - it is a statistical method which finds the relationship btw two column (input & output)
# this just says the direction (+ or -)
#
# co relation - this is used to check the relation bond between multiple columns strong or weak (0-1)
#
# scatter plot - it is used to check the co relation bond btw two column highly or weakly co related and also used to find inversly or sirectly propotional

# %%
# flow of supervised learning algorithm
# Regression
# 1 x,y 
# 2 train and test data 
# 3 model creation 
# 4 model training
# 5 model evaluation
# 6 prediction
#        x                                 y 
#     study hours                        score
#     sleep hours                        

#                         x+y
#     train data                        test data 
#     model creation                   model evaluation 
#     model training

# %%
# Linaer regression : it is supervised learning regression techinque which predicts continue value by finding best fit line to understand the relation between independent and dependent columns
# when to use linear regression?
# when data is linear or highly correlated between input and output then we use linear regression
# formula :  y = mx+c
# y --> predicted Value 
# m --> slope
# c --> intercept
# x --> new input
# intercept : it is the base or initial valu or starting value of y when x is 0
# intercept = 10 : when x=0 and y=10

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
x=df['YearsExperience']
y=df['Salary']
result = train_test_split(x,y,train_size=0.8)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)
ytrain.sort_index()
# Out:
# 0      39343.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('Salary_Data.csv')


x = df[['YearsExperience']]
y = df['Salary']

xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, random_state=42, train_size=0.8
)

model = LinearRegression()

model.fit(xtrain, ytrain)

prediction = model.predict(xtrain)

print(prediction)
plt.scatter(xtrain, ytrain, color='blue')
plt.plot(xtrain, prediction, color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression: Salary vs. Years of Experience')
plt.show()
# Out:
# [122386.880839   107308.77632215  63016.8443039   35687.77986711
#   46053.97672244  73383.04115923  52650.64744857  63959.2258362
#   63016.8443039   99769.72406372  37572.54293172  39457.30599632
#  110135.92091906  44169.21365784  92230.6718053  114847.82858057
#   80922.09341766 124271.6439036   89403.52720839  55477.79204548
#   62074.4627716   67728.75196542  81864.47494996  53593.02898087]
