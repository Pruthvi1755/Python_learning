# %%
# [10,2,5,8,3,4]
# key = 5
# o/p = 5 is found at index 2
l =[10,2,5,8,3,4]
key =0
found = False
for i in range (len(l)):
    if key == l[i]:
        print(f'key {key} is found at {i}')
        found = True
        break
        # i+=1
# if found == False:
if not found:
    print("key not found")
# Out:
# key not found

# %%
l =[10,2,5,8,3,4,5]
key =5
for i in range (len(l)):
    if key == l[i]:
        print(f'key {key} is found at {i}')
        break
else:
    print("key not found")
# Out:
# key 5 is found at 2
