# %%
# count how many odd and even numbers are there in a list

def evenorodd(n):
    even=0
    odd=0
    for i in l:
        if i!=0 and i%2==0:
            even+=1
        else:
            odd+=1
    print(f'total even numbers are - {even}')
    print(f'total odd numbers are - {odd}')
obj=evenorodd([1,2,3,4,5,6,7,8,9,0,0,0])
# Out:
# total even numbers are - 4
# total odd numbers are - 8

# %%
# find the common elements in the list
l1=[2,3,4,5,6,7,8,3,2,3,5,6,8,4,2,4,11]
l2=[2,3,5,8,0,7,4,11,6,78,8]
print(list(set(l1).intersection(set(l2))))
l3=[]

# without inbuilt function

for i in l1:
    if i in l2 and i not in l3:
        l3.append(i)
print(l3)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 11]
# [2, 3, 4, 5, 6, 7, 8, 11]
# [2, 3, 4, 5, 6, 7, 8, 3, 2, 3, 5, 6, 8, 4, 2, 4, 11]
