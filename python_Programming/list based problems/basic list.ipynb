# %%
n = int(input("n: "))
l1=[int(input('val: ')) for i in range(n)]
print(l1)

n = int(input("n: "))
l1=[]
for i in range(n):
    val=int(input('val: '))
    l1.append(val)
print(l1)

n  = int(input("n: "))
l1=eval(input())[:n]
print(l1)

# %%
#Map method
l1=list(map(int, input().split()))
print(l1)


#sum of list elements1
l1=[1,2,3,4,5]
res = 0
for i in l1:
    res+=i
print(res)

l1=[1,2,3,4,5,"don"]
res = 0
for i in l1:
    if type(i)==int or type(i)==float:
        res+=i
print(res)

l1=[1,2,3,4,5,"don",2.6]
res = 0
for i in l1:
    if type(i)==int or type(i)==float:
        res+=i
print(res)

l1=[1,2,3,4,5,"don"]
res = 0
for i in l1:
    if isinstance(i,(int,float,complex)):
        res+=i
print(res)

# %%
#Product of list elements
l1=[1,2,3,4,5]
res = 1
for i in l1:
    res*=i
print(res)
# ----or---
l1=[1,2,3,4,5,"don"]
res = 1
for i in l1:
    if isinstance(i,(int,float,complex)):
        res*=i
print(res)

# %%
#Difference of list elements
l1=[10,5,3,2]
res = l1[0]
for i in range(1,len(l1)):
 for i in l1[1:]:
    if len(l1)>0:
        res -= l1[i]
print(res)

# %%
#Largest element in list
l1 = [10,5,3,8,4,80,7]
if len(l1)>0:
    m=l1[0]
    for i in l1[1:]:
        if i>m:
            m=i
    print(m)

# %%
#Smallest element in list
l1 = [10,5,3,8,4,80,7]
if len(l1)>0:
    m=l1[0]
    for i in l1[1:]:
        if i<m:
            m=i
    print(m)

# %%
#Second largest element in a list
l1 = [10,5,3,8,4,80,7,80]
res =list(set(l1))
res.sort()
print(res[-2])

# %%
#Remove the duplicae elements in list
l1 = [1,2,3,4,1,7,8,9,10,7,10]
res=[]
for i in l1:
    if i not in res:
        res.append(i)
print(res)

# %%
#remove the target element in list(❌logic pgm)
l1=[1,2,3,1,1,1,1,4,5]
target=int(input('target: '))
for i in l1:
    if i==target:
        l1.remove(i)
print(l1)

l1=[1,2,3,1,1,1,1,4,5]
target=int(input('target: '))
res = []
for i in l1:
    if target!=i:
        res.append(i)
print(res)

l1=[1,2,3,1,1,1,1,4,5]
target=int(input('target: '))
while l1.count(target)>0:
    l1.remove(target)
print(l1)

l1=[1,2,3,1,1,1,1,4,5]
target=int(input('target: '))
i=0
while i<len(l1):
    if l1[i]==target:
        l1.remove(target)
    else:
        i+=1
print(l1)

l1=[1,2,3,1,1,1,1,4,5]
target=int(input('target: '))
i=0
while target in l1:
    l1.remove(target)
print(l1)

l1=[1,2,1,3,4,2,2,8,2]
target=int(input('target: '))
i=0
while i<len(l1):
    if l1[i]==target:
        del l1[i]
    else:
        i+=1
print(l1)

l1=[1,2,1,3,4,2,2,8,2]
for i in range(len(l1)):
    for j in range(i+1,len(l1)):
        if l1[j]==l1[i]:
            l1[j]=''
while '' in l1:
    l1.remove('')
print(l1)

# %%
#Second largest element in a list without inbuilt functions
l1=[10,20,30,560,2,3,560,87,100]
l1.sort()
if len(l1)==0:
    print('Empty String')
elif len(l1)==1:
    print(l1[0])
else:
    res=l1[-1]
    for i in range(len(l1)-2,-1,-1):
        if res!=l1[i]:
            res=l1[i]
            break
    print(res)

# %%
#without sort inbilt function
l1 = [-100,-50,-8,-59,-6]
largest=min(l1)
seclargest=min(l1)
for i in l1:
    if largest<i:
        seclargest=largest
        largest=i
    elif i>seclargest and i!=largest:
        seclargest=i
print(seclargest)

l1=[1000,1000,37,56,98,98,89,23,67]
l=0
sl=0
for i in range(len(l1)):
    if l1[i]>sl and l1[i]<l:
        sl=l1[i]
    elif l1[i]>l:
        sl=l
        l=l1[i]
print(sl)

# %%
# Map method
#syntax:map(datatype,list)
l1=['1','2','3','4','5']
res=map(int,l1)
print(list(res))


def cube(n):
    return n**3
l1=[1,2,3,4,5]
# res=map(cube,l1)
res=map(lambda n:n**3,l1)
print(list(res))

n=int(input('n: '))
l1=list(map(int,input().split()))[:n]   #slicing for remove extra elements
print(l1)

#One left Rotation of elements
n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
temp=l1[0]
for i in range(len(l1)-1):
    l1[i]=l1[i+1]
l1[-1]=temp
print(l1)

# %%
#kth time rotation
n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))%len(l1)
for val in range(k):
    temp=l1[0]
    for i in range(len(l1)-1):
        l1[i]=l1[i+1]
    l1[-1]=temp
print(l1)

n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))%len(l1)
for val in range(k):
    l1=l1[1:]+l1[:1]
print(l1)


n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))%len(l1)
l1=l1[k:]+l1[:k]
print(l1)

# %%
#one right Rotation of elements
n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
temp=l1[-1]
for i in range(len(l1)-1,0,-1):
    l1[i]=l1[i-1]
l1[0]=temp
print(l1)

# %%
#kth rotation
n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))
for val in range(k):
    temp=l1[-1]
    for i in range(len(l1)-1,0,-1):
        l1[i]=l1[i-1]
    l1[0]=temp
print(l1)

n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))
for val in range(k):
    l1=l1[-1:]+l1[:-1]
print(l1)

n=int(input('n: '))
l1=list(map(int,input().split()))[:n]
k=int(input('k: '))%len(l1)
l1=l1[-k:]+l1[:-k]
print(l1)
