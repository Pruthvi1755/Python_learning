# %% [markdown]
# 1-n prime number

# %%
n = int(input("n: "))
for val in range (2,n+1):
    count=0
    for i in range(2,val//2+1):
        if val%i==0:
            count+=1
            break
        
    if count == 0:
        print(val,end=' ')
# Out:
# 2 3 5 7 11 13 17 19

# %% [markdown]
# amstrong number from 1 - n
# strong -||-
# n strong number
# perfect number in the range of 1 - n
# n perfect numbers
